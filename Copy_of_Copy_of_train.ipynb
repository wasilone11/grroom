# %% [markdown]
# <a href="https://colab.research.google.com/github/wasilone11/grroom/blob/main/Copy_of_Copy_of_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check the gpu
# 1.  for tiny_model, tiny_plus_model only T4 and K80 are allowed.
# 2.  for big_model only P100, T4 and K80 are allowed.

# %%
from IPython.display import HTML, clear_output
from subprocess import getoutput
s = getoutput('nvidia-smi')
if 'K80' in s:gpu = 'K80'
elif 'T4' in s:gpu = 'T4'
elif 'P100' in s:gpu = 'P100'
else:
    gpu='DONT PROCEED'
display(HTML(f"<h1>{gpu}</h1>"))
# Out:
# <h1>T4</h1>

# %% [markdown]
# # Mount the drive and import necessary libraries

# %%
from google.colab import drive
from os import listdir, remove, makedirs
from os.path import join, exists
import random
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/darknet
# !chmod +x ./darknet
# !./darknet
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/darknet
# usage: ./darknet <function>

# %% [markdown]
# # Start Training from beginning
# 1.  No need to run below this, if you are going to **resume**. [Click here](#resume-cell) to go to the resume cell.

# %%
# change this path
inputpath="footwear_merged/f_heel_width_a5_case_3_1"
if "gdrive" not in inputpath:
    inputpath = "/gdrive/MyDrive/"+inputpath
if exists(inputpath):
    x = input("Which model you want to train?\n\t1. tiny model\n\t2. tiny plus model\n\t3. big model\n")
    dont_run=False
    if x=='1':model_type = "tiny_model"
    elif x=='2':model_type = "tiny_plus_model"
    elif x=='3':model_type = "big_model"
    else:
        dont_run=True
        clear_output()
        print("Enter correct input among 1,2 and 3.")
else:
    print(inputpath, "cannot be found please correct it.")
# Out:
# Which model you want to train?
# 	1. tiny model
# 	2. tiny plus model
# 	3. big model
# 1

# %% [markdown]
# ### Helper Functions

# %%
def check_existence(folder, count=0):
    tmp="" if count==0 else "_"+str(count)
    check_folder = folder+tmp
    if (check_folder in listdir(".")) and (len([k for k in listdir(check_folder) if ".weights" in k])!=0):
        count+=1
        return check_existence(folder, count)
    else:
        return check_folder
def get_all_files(folder:str, result:dict):
    tmp = sorted(listdir(folder))
    result[folder]=[i for i in tmp if (".jpg" in i) or (".txt" in i)]
    for i in tmp:
        if "." not in i:
            get_all_files(join(folder, i), result)
def get_images_txt(folder:str):
    data = {}
    get_all_files(folder, data)
    del data[folder]
    final_data = {}
    for i in data.keys():
        if len(data[i])==0:
            continue
        class_ = i[len(folder)+1:].split("/")[0]
        if class_ not in final_data.keys():
            final_data[class_]={}
        final_data[class_][i] = []
        for j in range(len(data[i])-1):
            if data[i][j][:data[i][j].rfind('.')]==data[i][j+1][:data[i][j+1].rfind('.')]:
                final_data[class_][i].append([i+'/'+data[i][j], i+'/'+data[i][j+1]])
                j+=1
    return final_data

# %% [markdown]
# ### Confirm the output folder

# %%
if not dont_run:
    clear_output()
    outputpath="_".join(inputpath.split("/")[3:])+"_"+model_type
    outputpath = check_existence(outputpath)
    print("Output folder is "+outputpath+".")
    x = input("Please confirm to create the output folder (y/n):")
    if x == 'y':
        if not exists(outputpath):
            makedirs(outputpath)
        print("Output folder created.")
    elif x == 'n':
        print("Output folder not created.")
    else:
        print("Please input valid character.")
# Out:
# Output folder is footwear_merged_f_heel_width_a5_case_3_1_tiny_model.
# Please confirm to create the output folder (y/n):y
# Output folder created.

# %% [markdown]
# ### Confirm the count of images and classes.
# 1.  Those numbers tells the count of pair of image and it's annotation.
# 2.  Adjust the threshold value to increase and decrease the classes.

# %%
threshold = 10
data = get_images_txt(inputpath)
key_list = sorted(list(data.keys()))
count=0
for i in key_list:
    l = sum([len(k) for k in data[i].values()])
    if l>threshold:
        print(count,i, l)
        count+=1
    else:
        del data[i]
x = input("Please confirm that classes and count of images are correct (y/n):")
if x == 'y':
    classes = sorted(data.keys())
    print("Classes selected.")
elif x == 'n':
    classes = None
    print("Classes not selected.")
else:
    classes = None
    print("Please input valid character.")
# Out:
# 0 no_heel 1049
# 1 slim_heel 1065
# 2 wide_heel 87
# Please confirm that classes and count of images are correct (y/n):y
# Classes selected.

# %%
for i in classes:
    print(i)
    for j in sorted(data[i].keys()):
        print(j, len(data[i][j]))
    print()
# Out:
# no_heel
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/ballerinas/women 255
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/boots/men 147
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/boots/women 120
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/sandal_shoe/men 133
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/sandal_shoe/women 132
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/slippers/men 132
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/no_heel/slippers/women 130
#
# slim_heel
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/slim_heel/ballerinas/women 207
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/slim_heel/boots/women 213
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/slim_heel/pumps/women 216
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/slim_heel/sandal_shoe/women 213
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/slim_heel/slippers/women 216
#
# wide_heel
# /gdrive/MyDrive/footwear_merged/f_heel_width_a5_case_3_1/wide_heel/ballerinas/women 87

# %% [markdown]
# ### Change ids in the annotation files
# 1.  This cell will take some time.

# %%
for id in range(len(classes)):
    tmp = 0
    cls = classes[id]
    print(cls+"-", end = " ")
    for i in data[cls].keys():
        for j in data[cls][i]:
            f = open(j[1],'r')
            s = [k.split(" ") for k in f.read().split('\n')]
            s = [k for k in s if len(k)==5]
            s = [[str(id)]+k[1:] for k in s]
            s = "\n".join([" ".join(k) for k in s])+"\n"
            f.close()
            f = open(j[1],'w')
            f.write(s)
            f.close()
            tmp+=1
            if tmp%100==0:
                print(tmp, end=".. ")
    print(tmp)
# Out:
# no_heel- 100.. 200.. 300.. 400.. 500.. 600.. 700.. 800.. 900.. 1000.. 1049
# slim_heel- 100.. 200.. 300.. 400.. 500.. 600.. 700.. 800.. 900.. 1000.. 1065
# wide_heel- 87

# %% [markdown]
# ### Save the training data

# %%
train=[]
for id in range(len(classes)):
    for i in data[classes[id]].keys():
        train.extend([k[0] for k in data[classes[id]][i]])
train=[i for i in train if ".txt" not in i]
random.shuffle(train)
l=len(train)
valid=train[int(l*5/6):]
train=train[:int(l*5/6)]
f=open(join(outputpath, model_type+"_train.txt"),'w')
f.write("\n".join(train))
f.close()
f=open(join(outputpath, model_type+"_valid.txt"),'w')
f.write("\n".join(valid))
f.close()

# %% [markdown]
# ### Save the names file and data file

# %%
f=open(join(outputpath, model_type+"_obj.names"),'w')
f.write("\n".join(classes))
f.close()
numClass=len(classes)
objdata=["classes= "+str(numClass),
         "train = "+join(outputpath, model_type+"_train.txt"),
         "valid = "+join(outputpath, model_type+"_valid.txt"),
         "names = "+join(outputpath, model_type+"_obj.names"),
         "backup = "+outputpath+"/"]
f=open(join(outputpath, model_type+"_obj.data"),"w")
f.write("\n".join(objdata))
f.close()

# %% [markdown]
# ### Copy the appropriate config file

# %%
import shutil
dest_cfg_name = model_type+"_yolov4.cfg"
if model_type == "tiny_model":
    src_cfg_name = "yolov4-tiny-custom.cfg"
    netSize=416
    batch=64
    subdiv=1
    max_batches_multiplier = 3000
    default_max_batch = 500200
elif model_type == "tiny_plus_model":
    src_cfg_name = "yolov4-tiny-custom.cfg"
    netSize=608
    batch=64
    subdiv=2
    max_batches_multiplier = 3000
    default_max_batch = 500200
elif model_type == "big_model":
    src_cfg_name = "yolov4-custom.cfg"
    netSize=416
    batch=64
    subdiv=1
    max_batches_multiplier = 2000
    default_max_batch = 500500
if dest_cfg_name not in listdir(outputpath):
    shutil.copy("cfg/"+src_cfg_name, outputpath+'/'+dest_cfg_name)
else:
    remove(outputpath+'/'+dest_cfg_name)
    shutil.copy("cfg/"+src_cfg_name, outputpath+'/'+dest_cfg_name)

# %% [markdown]
# ### Configure the training details

# %%
#change number of class and filters
comm='s/classes=80/classes='+str(numClass)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/filters=255/filters='+str((numClass+5)*3)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name

#change number of steps and max batches
max_batches=max(6000,(numClass)*max_batches_multiplier)
comm='s/max_batches\ =\ '+str(default_max_batch)+'/max_batches\ =\ '+str(max_batches)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/steps=400000,450000/steps='+str(int(0.8*max_batches))+','+str(int(0.9*max_batches))+"/"
# !sed -i $comm $outputpath/$dest_cfg_name

#can be multiple of 32 or 608(but makes training slow)
comm='s/width=416/width='+str(netSize)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/height=416/height='+str(netSize)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name

comm='s/batch=64/batch='+str(batch)+'/'
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/subdivisions=1/subdivisions='+str(subdiv)+'/'
# !sed -i $comm $outputpath/$dest_cfg_name

# %% [markdown]
# ### Download the weight if doesn't exist

# %%
if "yolov4.conv.137" not in listdir():
    # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
if "yolov4-tiny.conv.29" not in listdir():
    # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29

# %% [markdown]
# # Start the training
# 1.  if you are running from the top, then run the below cell directly.
# 2.  if you have done the configurations before hand, and want to run this cell, then define the outputpath variable in some other cell, and then run the below cell.
# 3.  outputpath variable contains the folder name in which model will be saved.

# %%
obj_file = None
cfg_file = None

if "tiny_model" in outputpath : model_name = "yolov4-tiny.conv.29"
elif "tiny_plus_model" in outputpath : model_name = "yolov4-tiny.conv.29"
elif "big_model" in outputpath : model_name = "yolov4.conv.137"

for i in listdir(outputpath):
    if "obj.data" in i:
        obj_file = join(outputpath, i)
    elif ".cfg" in i:
        cfg_file = join(outputpath, i)

if obj_file == None:
    print(".data file not found in", outputpath)

if cfg_file ==None:
    print(".cfg file not found in", outputpath)

if (obj_file != None) and (cfg_file != None):
    # !./darknet detector train $obj_file $cfg_file $model_name -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8515: 0.229910, 0.211413 avg loss, 0.000026 rate, 0.484202 seconds, 544960 images, 0.222182 hours left
# Loaded: 0.801657 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.825236), count: 32, class_loss = 0.147382, iou_loss = 0.288733, total_loss = 0.436115
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.752701), count: 62, class_loss = 0.274920, iou_loss = 6.636970, total_loss = 6.911890
#  total_bbox = 723659, rewritten_bbox = 0.090789 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8516: 0.211382, 0.211410 avg loss, 0.000026 rate, 0.445897 seconds, 545024 images, 0.221708 hours left
# Loaded: 0.927203 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.786830), count: 26, class_loss = 0.120603, iou_loss = 0.223768, total_loss = 0.344370
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.755228), count: 52, class_loss = 0.296280, iou_loss = 5.372488, total_loss = 5.668768
#  total_bbox = 723737, rewritten_bbox = 0.090779 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8517: 0.208692, 0.211138 avg loss, 0.000026 rate, 0.587008 seconds, 545088 images, 0.221169 hours left
# Loaded: 0.683627 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.781184), count: 34, class_loss = 0.156076, iou_loss = 0.422415, total_loss = 0.578490
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.716742), count: 44, class_loss = 0.172975, iou_loss = 5.848177, total_loss = 6.021153
#  total_bbox = 723815, rewritten_bbox = 0.090769 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8518: 0.164800, 0.206504 avg loss, 0.000026 rate, 0.699515 seconds, 545152 images, 0.220988 hours left
# Loaded: 0.688304 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.784601), count: 36, class_loss = 0.139558, iou_loss = 0.222225, total_loss = 0.361783
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.742076), count: 51, class_loss = 0.359961, iou_loss = 5.560750, total_loss = 5.920711
#  total_bbox = 723902, rewritten_bbox = 0.090758 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8519: 0.250018, 0.210856 avg loss, 0.000026 rate, 0.640390 seconds, 545216 images, 0.220630 hours left
# Loaded: 0.672358 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.769411), count: 22, class_loss = 0.091564, iou_loss = 0.201511, total_loss = 0.293075
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.776565), count: 64, class_loss = 0.326810, iou_loss = 5.539352, total_loss = 5.866162
#  total_bbox = 723988, rewritten_bbox = 0.090747 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8520: 0.209436, 0.210714 avg loss, 0.000026 rate, 0.411976 seconds, 545280 images, 0.220199 hours left
# Loaded: 0.923118 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.744122), count: 20, class_loss = 0.162509, iou_loss = 0.144431, total_loss = 0.306940
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.757579), count: 64, class_loss = 0.367595, iou_loss = 5.400103, total_loss = 5.767698
#  total_bbox = 724072, rewritten_bbox = 0.090737 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8521: 0.265325, 0.216175 avg loss, 0.000026 rate, 0.529053 seconds, 545344 images, 0.219443 hours left
# Loaded: 0.792632 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.815437), count: 25, class_loss = 0.144592, iou_loss = 0.220781, total_loss = 0.365373
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.729392), count: 49, class_loss = 0.337356, iou_loss = 7.243286, total_loss = 7.580642
#  total_bbox = 724146, rewritten_bbox = 0.090728 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8522: 0.241223, 0.218680 avg loss, 0.000026 rate, 0.607129 seconds, 545408 images, 0.219181 hours left
# Loaded: 0.635985 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.794979), count: 40, class_loss = 0.172748, iou_loss = 0.348647, total_loss = 0.521395
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.758037), count: 54, class_loss = 0.214178, iou_loss = 7.317637, total_loss = 7.531815
#  total_bbox = 724240, rewritten_bbox = 0.090716 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8523: 0.193707, 0.216182 avg loss, 0.000026 rate, 0.455050 seconds, 545472 images, 0.218848 hours left
# Loaded: 0.826874 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.801605), count: 40, class_loss = 0.230770, iou_loss = 0.261688, total_loss = 0.492458
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.756098), count: 41, class_loss = 0.181768, iou_loss = 3.673295, total_loss = 3.855064
#  total_bbox = 724321, rewritten_bbox = 0.090706 %
#
#  (next mAP calculation at 8524 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.13 %, best = 64.99 %
#  8524: 0.206511, 0.215215 avg loss, 0.000026 rate, 0.431165 seconds, 545536 images, 0.218105 hours left
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 368
#  detections_count = 1687, unique_truth_count = 540
# class_id = 0, name = no_heel, ap = 50.63%   	 (TP = 105, FP = 55)
# class_id = 1, name = slim_heel, ap = 70.39%   	 (TP = 205, FP = 63)
# class_id = 2, name = wide_heel, ap = 70.20%   	 (TP = 10, FP = 0)
#
#  for conf_thresh = 0.25, precision = 0.73, recall = 0.59, F1-score = 0.65
#  for conf_thresh = 0.25, TP = 320, FP = 118, FN = 220, average IoU = 52.36 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.637414, or 63.74 %
# Total Detection Time: 11 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.637414
# Loaded: 0.000056 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.817218), count: 24, class_loss = 0.089421, iou_loss = 0.320344, total_loss = 0.409765
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.766862), count: 57, class_loss = 0.294326, iou_loss = 4.979593, total_loss = 5.273920
#  total_bbox = 724402, rewritten_bbox = 0.090696 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8525: 0.192101, 0.212904 avg loss, 0.000026 rate, 0.593763 seconds, 545600 images, 0.232454 hours left
# Loaded: 0.808474 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.748434), count: 29, class_loss = 0.064918, iou_loss = 0.277732, total_loss = 0.342650
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.709942), count: 52, class_loss = 0.323360, iou_loss = 5.503520, total_loss = 5.826880
#  total_bbox = 724483, rewritten_bbox = 0.090685 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8526: 0.194435, 0.211057 avg loss, 0.000026 rate, 0.489050 seconds, 545664 images, 0.230913 hours left
# Loaded: 0.995308 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.807006), count: 27, class_loss = 0.136598, iou_loss = 0.228137, total_loss = 0.364735
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.715233), count: 59, class_loss = 0.409032, iou_loss = 5.527228, total_loss = 5.936260
#  total_bbox = 724569, rewritten_bbox = 0.090675 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8527: 0.273076, 0.217259 avg loss, 0.000026 rate, 0.496473 seconds, 545728 images, 0.230312 hours left
# Loaded: 0.626952 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.804569), count: 30, class_loss = 0.183828, iou_loss = 0.241544, total_loss = 0.425372
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.806617), count: 47, class_loss = 0.220868, iou_loss = 5.189886, total_loss = 5.410754
#  total_bbox = 724646, rewritten_bbox = 0.090665 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8528: 0.202561, 0.215789 avg loss, 0.000026 rate, 0.577811 seconds, 545792 images, 0.229969 hours left
# Loaded: 0.743054 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.807968), count: 37, class_loss = 0.091804, iou_loss = 0.322924, total_loss = 0.414729
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.693207), count: 53, class_loss = 0.294470, iou_loss = 6.097534, total_loss = 6.392004
#  total_bbox = 724736, rewritten_bbox = 0.090792 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8529: 0.193410, 0.213551 avg loss, 0.000026 rate, 0.529436 seconds, 545856 images, 0.229249 hours left
# Loaded: 0.870170 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.788931), count: 28, class_loss = 0.110238, iou_loss = 0.228660, total_loss = 0.338898
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.718036), count: 49, class_loss = 0.285403, iou_loss = 5.892415, total_loss = 6.177817
#  total_bbox = 724813, rewritten_bbox = 0.090782 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8530: 0.198090, 0.212005 avg loss, 0.000026 rate, 0.631666 seconds, 545920 images, 0.228622 hours left
# Loaded: 0.671815 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.791152), count: 33, class_loss = 0.207476, iou_loss = 0.248887, total_loss = 0.456363
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.741161), count: 45, class_loss = 0.239712, iou_loss = 4.961251, total_loss = 5.200963
#  total_bbox = 724891, rewritten_bbox = 0.090772 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8531: 0.223850, 0.213189 avg loss, 0.000026 rate, 0.423797 seconds, 545984 images, 0.228296 hours left
# Loaded: 0.822203 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.794935), count: 38, class_loss = 0.135271, iou_loss = 0.496506, total_loss = 0.631778
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.792582), count: 37, class_loss = 0.201085, iou_loss = 3.064023, total_loss = 3.265109
#  total_bbox = 724966, rewritten_bbox = 0.090763 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8532: 0.168404, 0.208711 avg loss, 0.000026 rate, 0.614432 seconds, 546048 images, 0.227441 hours left
# Loaded: 0.716500 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.812933), count: 29, class_loss = 0.132074, iou_loss = 0.259519, total_loss = 0.391593
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.759782), count: 63, class_loss = 0.286211, iou_loss = 6.454250, total_loss = 6.740461
#  total_bbox = 725058, rewritten_bbox = 0.090751 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8533: 0.209376, 0.208777 avg loss, 0.000026 rate, 0.567584 seconds, 546112 images, 0.227034 hours left
# Loaded: 0.741169 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.827176), count: 29, class_loss = 0.089436, iou_loss = 0.290492, total_loss = 0.379928
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.748585), count: 64, class_loss = 0.333126, iou_loss = 8.242153, total_loss = 8.575279
#  total_bbox = 725151, rewritten_bbox = 0.090740 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8534: 0.211513, 0.209051 avg loss, 0.000026 rate, 0.509974 seconds, 546176 images, 0.226429 hours left
# Loaded: 0.850478 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.823718), count: 34, class_loss = 0.098990, iou_loss = 0.348093, total_loss = 0.447082
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.742769), count: 42, class_loss = 0.315578, iou_loss = 5.853272, total_loss = 6.168850
#  total_bbox = 725227, rewritten_bbox = 0.090730 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8535: 0.207521, 0.208898 avg loss, 0.000026 rate, 0.501950 seconds, 546240 images, 0.225785 hours left
# Loaded: 0.816149 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.814566), count: 46, class_loss = 0.164277, iou_loss = 0.361177, total_loss = 0.525454
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.718053), count: 43, class_loss = 0.294022, iou_loss = 4.446961, total_loss = 4.740983
#  total_bbox = 725316, rewritten_bbox = 0.090719 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8536: 0.229405, 0.210949 avg loss, 0.000026 rate, 0.610530 seconds, 546304 images, 0.225274 hours left
# Loaded: 0.697875 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.788413), count: 27, class_loss = 0.133472, iou_loss = 0.206565, total_loss = 0.340037
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.740254), count: 63, class_loss = 0.309957, iou_loss = 5.114644, total_loss = 5.424601
#  total_bbox = 725406, rewritten_bbox = 0.090708 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8537: 0.221973, 0.212051 avg loss, 0.000026 rate, 0.633560 seconds, 546368 images, 0.224860 hours left
# Loaded: 0.668732 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.827313), count: 28, class_loss = 0.168309, iou_loss = 0.293430, total_loss = 0.461738
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.717387), count: 59, class_loss = 0.397270, iou_loss = 4.742508, total_loss = 5.139778
#  total_bbox = 725493, rewritten_bbox = 0.090697 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8538: 0.283038, 0.219150 avg loss, 0.000026 rate, 0.718026 seconds, 546432 images, 0.224324 hours left
# Loaded: 0.557717 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.757713), count: 25, class_loss = 0.200498, iou_loss = 0.303664, total_loss = 0.504162
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.750462), count: 58, class_loss = 0.349188, iou_loss = 6.677066, total_loss = 7.026254
#  total_bbox = 725576, rewritten_bbox = 0.090687 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8539: 0.275112, 0.224746 avg loss, 0.000026 rate, 0.674244 seconds, 546496 images, 0.223860 hours left
# Loaded: 0.659401 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.798177), count: 48, class_loss = 0.287949, iou_loss = 0.581038, total_loss = 0.868986
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.651356), count: 68, class_loss = 0.363844, iou_loss = 7.825420, total_loss = 8.189264
#  total_bbox = 725692, rewritten_bbox = 0.090810 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8540: 0.326197, 0.234891 avg loss, 0.000026 rate, 0.503002 seconds, 546560 images, 0.223199 hours left
# Loaded: 0.721668 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.801489), count: 46, class_loss = 0.113780, iou_loss = 0.439230, total_loss = 0.553010
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.758586), count: 43, class_loss = 0.204654, iou_loss = 3.443073, total_loss = 3.647726
#  total_bbox = 725781, rewritten_bbox = 0.090799 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  

# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.704331), count: 55, class_loss = 0.267616, iou_loss = 6.778192, total_loss = 7.045808
#  total_bbox = 728753, rewritten_bbox = 0.091115 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8576: 0.190795, 0.217093 avg loss, 0.000026 rate, 0.400671 seconds, 548864 images, 0.203962 hours left
# Loaded: 0.884866 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.789974), count: 37, class_loss = 0.182232, iou_loss = 0.338820, total_loss = 0.521052
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.718127), count: 50, class_loss = 0.305593, iou_loss = 5.492324, total_loss = 5.797917
#  total_bbox = 728840, rewritten_bbox = 0.091104 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8577: 0.244182, 0.219802 avg loss, 0.000026 rate, 0.594219 seconds, 548928 images, 0.203510 hours left
# Loaded: 0.864783 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.821952), count: 29, class_loss = 0.130993, iou_loss = 0.418196, total_loss = 0.549189
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.755442), count: 45, class_loss = 0.227471, iou_loss = 3.816603, total_loss = 4.044075
#  total_bbox = 728914, rewritten_bbox = 0.091094 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8578: 0.179463, 0.215768 avg loss, 0.000026 rate, 0.526827 seconds, 548992 images, 0.203213 hours left
# Loaded: 0.846809 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.782457), count: 30, class_loss = 0.202332, iou_loss = 0.253241, total_loss = 0.455573
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.704343), count: 44, class_loss = 0.217094, iou_loss = 5.040987, total_loss = 5.258082
#  total_bbox = 728988, rewritten_bbox = 0.091085 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8579: 0.209994, 0.215191 avg loss, 0.000026 rate, 0.462998 seconds, 549056 images, 0.202812 hours left
# Loaded: 0.880847 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.830024), count: 33, class_loss = 0.137721, iou_loss = 0.277940, total_loss = 0.415661
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.765685), count: 52, class_loss = 0.227001, iou_loss = 5.706650, total_loss = 5.933651
#  total_bbox = 729073, rewritten_bbox = 0.091075 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8580: 0.182582, 0.211930 avg loss, 0.000026 rate, 0.378370 seconds, 549120 images, 0.202316 hours left
# Loaded: 0.848075 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.783029), count: 38, class_loss = 0.146073, iou_loss = 0.373248, total_loss = 0.519320
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.689400), count: 49, class_loss = 0.349822, iou_loss = 4.719614, total_loss = 5.069435
#  total_bbox = 729160, rewritten_bbox = 0.091064 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8581: 0.248236, 0.215561 avg loss, 0.000026 rate, 0.635987 seconds, 549184 images, 0.201762 hours left
# Loaded: 0.732417 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.779164), count: 34, class_loss = 0.134556, iou_loss = 0.400370, total_loss = 0.534926
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.724097), count: 39, class_loss = 0.204513, iou_loss = 3.310176, total_loss = 3.514689
#  total_bbox = 729233, rewritten_bbox = 0.091055 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8582: 0.169806, 0.210985 avg loss, 0.000026 rate, 0.455820 seconds, 549248 images, 0.201471 hours left
# Loaded: 0.934024 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.796626), count: 27, class_loss = 0.167285, iou_loss = 0.260247, total_loss = 0.427532
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.721707), count: 55, class_loss = 0.304469, iou_loss = 5.287374, total_loss = 5.591843
#  total_bbox = 729315, rewritten_bbox = 0.091044 %
#
#  (next mAP calculation at 8638 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 63.74 %, best = 64.99 %
#  8583: 0.236140, 0.213501 avg loss, 0.000026 rate, 0.697038 seconds, 549312 images, 0.200836 hours left
# Loaded: 0.552334 seconds - performance bottleneck on CPU or Disk HDD/SSD
# ...
#  8980: 0.206434, 0.206835 avg loss, 0.000026 rate, 0.553311 seconds, 574720 images, 0.046405 hours left
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 368
#  detections_count = 1648, unique_truth_count = 540
# class_id = 0, name = no_heel, ap = 50.27%   	 (TP = 103, FP = 54)
# class_id = 1, name = slim_heel, ap = 70.74%   	 (TP = 208, FP = 60)
# class_id = 2, name = wide_heel, ap = 71.15%   	 (TP = 10, FP = 0)
#
#  for conf_thresh = 0.25, precision = 0.74, recall = 0.59, F1-score = 0.66
#  for conf_thresh = 0.25, TP = 321, FP = 114, FN = 219, average IoU = 52.82 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.640524, or 64.05 %
# Total Detection Time: 11 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.640524
# Loaded: 0.000069 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.808219), count: 27, class_loss = 0.154157, iou_loss = 0.307933, total_loss = 0.462090
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.720655), count: 46, class_loss = 0.289998, iou_loss = 5.328928, total_loss = 5.618926
#  total_bbox = 763099, rewritten_bbox = 0.091731 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8981: 0.222335, 0.208385 avg loss, 0.000026 rate, 0.466472 seconds, 574784 images, 0.046641 hours left
# Loaded: 0.861946 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.792183), count: 29, class_loss = 0.133615, iou_loss = 0.181695, total_loss = 0.315310
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.754378), count: 56, class_loss = 0.251465, iou_loss = 4.152534, total_loss = 4.403998
#  total_bbox = 763184, rewritten_bbox = 0.091721 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8982: 0.192788, 0.206825 avg loss, 0.000026 rate, 0.536819 seconds, 574848 images, 0.046199 hours left
# Loaded: 0.701127 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.811661), count: 39, class_loss = 0.157731, iou_loss = 0.313052, total_loss = 0.470783
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.725919), count: 45, class_loss = 0.188437, iou_loss = 5.962109, total_loss = 6.150546
#  total_bbox = 763268, rewritten_bbox = 0.091711 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8983: 0.173337, 0.203476 avg loss, 0.000026 rate, 0.609419 seconds, 574912 images, 0.045807 hours left
# Loaded: 0.713657 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.800719), count: 36, class_loss = 0.198256, iou_loss = 0.294390, total_loss = 0.492646
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.755125), count: 56, class_loss = 0.346562, iou_loss = 4.024171, total_loss = 4.370733
#  total_bbox = 763360, rewritten_bbox = 0.091700 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8984: 0.272652, 0.210394 avg loss, 0.000026 rate, 0.548566 seconds, 574976 images, 0.045411 hours left
# Loaded: 0.722301 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.787331), count: 37, class_loss = 0.268204, iou_loss = 0.321743, total_loss = 0.589947
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.723838), count: 49, class_loss = 0.287687, iou_loss = 6.855192, total_loss = 7.142879
#  total_bbox = 763446, rewritten_bbox = 0.091690 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8985: 0.278213, 0.217176 avg loss, 0.000026 rate, 0.662311 seconds, 575040 images, 0.045013 hours left
# Loaded: 0.642591 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.804149), count: 22, class_loss = 0.099683, iou_loss = 0.197022, total_loss = 0.296704
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.754719), count: 62, class_loss = 0.311395, iou_loss = 7.300486, total_loss = 7.611881
#  total_bbox = 763530, rewritten_bbox = 0.091679 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8986: 0.205780, 0.216036 avg loss, 0.000026 rate, 0.499266 seconds, 575104 images, 0.044620 hours left
# Loaded: 0.804156 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.760253), count: 40, class_loss = 0.200844, iou_loss = 0.418403, total_loss = 0.619247
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.679015), count: 67, class_loss = 0.532220, iou_loss = 7.570701, total_loss = 8.102921
#  total_bbox = 763637, rewritten_bbox = 0.091667 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8987: 0.366839, 0.231116 avg loss, 0.000026 rate, 0.401144 seconds, 575168 images, 0.044219 hours left
# Loaded: 1.046465 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.765050), count: 23, class_loss = 0.157960, iou_loss = 0.162138, total_loss = 0.320098
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.712978), count: 57, class_loss = 0.346307, iou_loss = 7.593731, total_loss = 7.940037
#  total_bbox = 763717, rewritten_bbox = 0.091657 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8988: 0.252419, 0.233247 avg loss, 0.000026 rate, 0.690292 seconds, 575232 images, 0.043820 hours left
# Loaded: 0.590008 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.800148), count: 34, class_loss = 0.127533, iou_loss = 0.295514, total_loss = 0.423046
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.689632), count: 50, class_loss = 0.384908, iou_loss = 4.697467, total_loss = 5.082376
#  total_bbox = 763801, rewritten_bbox = 0.091647 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8989: 0.256499, 0.235572 avg loss, 0.000026 rate, 0.409260 seconds, 575296 images, 0.043440 hours left
# Loaded: 0.978703 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.779728), count: 27, class_loss = 0.080487, iou_loss = 0.338267, total_loss = 0.418754
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.781913), count: 66, class_loss = 0.315364, iou_loss = 6.711154, total_loss = 7.026517
#  total_bbox = 763894, rewritten_bbox = 0.091636 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8990: 0.198165, 0.231831 avg loss, 0.000026 rate, 0.505476 seconds, 575360 images, 0.043036 hours left
# Loaded: 0.677285 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.783392), count: 41, class_loss = 0.185525, iou_loss = 0.518089, total_loss = 0.703614
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.709690), count: 43, class_loss = 0.266350, iou_loss = 3.669682, total_loss = 3.936032
#  total_bbox = 763978, rewritten_bbox = 0.091626 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8991: 0.226215, 0.231270 avg loss, 0.000026 rate, 0.643715 seconds, 575424 images, 0.042647 hours left
# Loaded: 0.726127 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.804962), count: 35, class_loss = 0.151471, iou_loss = 0.354431, total_loss = 0.505903
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.741008), count: 48, class_loss = 0.297953, iou_loss = 4.414402, total_loss = 4.712355
#  total_bbox = 764061, rewritten_bbox = 0.091616 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8992: 0.224960, 0.230639 avg loss, 0.000026 rate, 0.499324 seconds, 575488 images, 0.042253 hours left
# Loaded: 0.758916 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.802500), count: 35, class_loss = 0.111891, iou_loss = 0.316305, total_loss = 0.428196
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.725762), count: 54, class_loss = 0.305201, iou_loss = 5.173181, total_loss = 5.478382
#  total_bbox = 764150, rewritten_bbox = 0.091605 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8993: 0.208804, 0.228455 avg loss, 0.000026 rate, 0.491199 seconds, 575552 images, 0.041858 hours left
# Loaded: 0.736569 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.832055), count: 45, class_loss = 0.197639, iou_loss = 0.371946, total_loss = 0.569585
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.740213), count: 50, class_loss = 0.182028, iou_loss = 5.724870, total_loss = 5.906898
#  total_bbox = 764245, rewritten_bbox = 0.091594 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8994: 0.190067, 0.224616 avg loss, 0.000026 rate, 0.394622 seconds, 575616 images, 0.041464 hours left
# Loaded: 1.034510 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.818203), count: 33, class_loss = 0.096312, iou_loss = 0.267218, total_loss = 0.363530
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.751095), count: 58, class_loss = 0.293846, iou_loss = 8.949850, total_loss = 9.243696
#  total_bbox = 764336, rewritten_bbox = 0.091583 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8995: 0.195315, 0.221686 avg loss, 0.000026 rate, 0.484616 seconds, 575680 images, 0.041068 hours left
# Loaded: 0.855663 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.821882), count: 25, class_loss = 0.142540, iou_loss = 0.199878, total_loss = 0.342418
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.726304), count: 52, class_loss = 0.294220, iou_loss = 5.382981, total_loss = 5.677201
#  total_bbox = 764413, rewritten_bbox = 0.091574 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8996: 0.218627, 0.221380 avg loss, 0.000026 rate, 0.400654 seconds, 575744 images, 0.040678 hours left
# Loaded: 1.044805 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.791585), count: 40, class_loss = 0.181385, iou_loss = 0.379387, total_loss = 0.560771
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.737418), count: 46, class_loss = 0.306732, iou_loss = 6.502172, total_loss = 6.808904
#  total_bbox = 764499, rewritten_bbox = 0.091563 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8997: 0.244316, 0.223674 avg loss, 0.000026 rate, 0.588996 seconds, 575808 images, 0.040286 hours left
# Loaded: 0.810612 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.797267), count: 32, class_loss = 0.112837, iou_loss = 0.390656, total_loss = 0.503494
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.770367), count: 59, class_loss = 0.281132, iou_loss = 7.958416, total_loss = 8.239549
#  total_bbox = 764590, rewritten_bbox = 0.091552 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8998: 0.197221, 0.221029 avg loss, 0.000026 rate, 0.563743 seconds, 575872 images, 0.039896 hours left
# Loaded: 0.625347 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.795845), count: 50, class_loss = 0.233815, iou_loss = 0.344771, total_loss = 0.578586
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.735096), count: 40, class_loss = 0.264502, iou_loss = 2.669274, total_loss = 2.933776
#  total_bbox = 764680, rewritten_bbox = 0.091542 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  8999: 0.249415, 0.223867 avg loss, 0.000026 rate, 0.441410 seconds, 575936 images, 0.039505 hours left
# Loaded: 0.000049 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.807125), count: 25, class_loss = 0.150121, iou_loss = 0.229287, total_loss = 0.379408
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.751799), count: 60, class_loss = 0.311378, iou_loss = 5.580878, total_loss = 5.892256
#  total_bbox = 764765, rewritten_bbox = 0.091531 %
#
#  (next mAP calculation at 9094 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.5 = 64.05 %, best = 64.99 %
#  9000: 0.230991, 0.224580 avg loss, 0.000026 rate, 0.412054 seconds, 576000 images, 0.039113 hours left
#
#  calculation mAP (mean average precision)...
#  Detection layer: 30 - type = 28
#  Detection layer: 37 - type = 28
# 368
#  detections_count = 1648, unique_truth_count = 540
# class_id = 0, name = no_heel, ap = 50.13%   	 (TP = 103, FP = 54)
# class_id = 1, name = slim_heel, ap = 70.74%   	 (TP = 207, FP = 60)
# class_id = 2, name = wide_heel, ap = 70.89%   	 (TP = 10, FP = 0)
#
#  for conf_thresh = 0.25, precision = 0.74, recall = 0.59, F1-score = 0.66
#  for conf_thresh = 0.25, TP = 320, FP = 114, FN = 220, average IoU = 52.75 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.639242, or 63.92 %
# Total Detection Time: 11 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.639242
# Saving weights to footwear_merged_f_heel_width_a5_case_3_1_tiny_model//tiny_model_yolov4_9000.weights
# Saving weights to footwear_merged_f_heel_width_a5_case_3_1_tiny_model//tiny_model_yolov4_last.weights
# Saving weights to footwear_merged_f_heel_width_a5_case_3_1_tiny_model//tiny_model_yolov4_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %% [markdown]
# <a name="resume-cell"></a>
# # Resume the training
# 1. For resuming the training process, it is complulsory to define the outputpath.
# 2.  outputpath variable contains the folder name in which model will be saved.

# %%
outputpath = input("Write the outputpath where previous training was done?\n")
clear_output()

obj_file = None
cfg_file = None
last_weight = None
folder_exists = exists(outputpath)
if folder_exists:
    for i in listdir(outputpath):
        if "obj.data" in i:
            obj_file = join(outputpath, i)
        elif ".cfg" in i:
            cfg_file = join(outputpath, i)
        elif "last.weights" in i:
            last_weight = join(outputpath, i)
else:
    print(outputpath, "does not exist please check the name.")

if (obj_file == None) and (folder_exists):
    print(".data file not found in", outputpath)
if (cfg_file ==None) and (folder_exists):
    print(".cfg file not found in", outputpath)
if (last_weight ==None) and (folder_exists):
    print("last.weights file not found in", outputpath)

if (obj_file != None) and (cfg_file != None) and (last_weight != None):
    # !./darknet detector train $obj_file $cfg_file $last_weight -dont_show -map
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-098af8b3c002> in <module>()
# ----> 1 outputpath = input("Write the outputpath where previous training was done?\n")
#       2 clear_output()
#       3
#       4 obj_file = None
#       5 cfg_file = None
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
